# %% [markdown]
# # DL Training on Study01
#
# Train the lateral-movement detector on study01 only. Keep the reusable logic in `src/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
SRC = ROOT / 'src'
sys.path.insert(0, str(SRC))

# Reuse the existing training code path until the DL helpers are split out further.
from train import parse_args, train

args = parse_args()
args.study = 'study01'
args.participant = 'all'
args.epochs = 60
args.batch = 32
args.window = 1.0
args.stride = 0.25
args.n_ics = 58
args.patience = 15

# %%
# Execute training from the notebook cell when you are ready.
# train(args)
